# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
pd.set_option('display.max_columns', 150) # displays all columns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
# Out:
# /kaggle/input/churn-telecomm/train.csv
# /kaggle/input/dfc-state/DFC_STATE.csv

# %% [markdown]
# # Dimensionality Reduction - PCA

# %% [markdown]
# # 01 - Data Preparation

# %%
# Load the training data from the specified address
train_original = pd.read_csv('/kaggle/input/dfc-state/DFC_STATE.csv')

# %%
# Create a working copy of the original DataFrame
train_data = train_original.copy()

# Print basic dataset info
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 39 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   State                                                                                    56 non-null     object
#  1   Transfusions- Better than expected (STATE)                                               56 non-null     int64
#  2   Transfusions- As expected (STATE)                                                        56 non-null     int64
#  3   Transfusions- Worse than expected (STATE)                                                56 non-null     int64
#  4   Infection- Better than expected (STATE)                                                  56 non-null     int64
#  5   Infection- As expected (STATE)                                                           56 non-null     int64
#  6   Infection- Worse than expected (STATE)                                                   56 non-null     int64
#  7   Percentage of adult HD patients with Kt/V>=1.2                                           55 non-null     float64
#  8   Percentage Of Adult PD Patients With Kt/V>=1.7                                           54 non-null     float64
#  9   Percentage Of Pediatric HD Patients With Kt/V>=1.2                                       49 non-null     float64
#  10  Percentage Of Pediatric PD Patients With Kt/V>=1.8                                       46 non-null     float64
#  11  Percentage Of Pediatric HD Patients With nPCR In Use                                     51 non-null     float64
#  12  Fistula Rate - Better Than Expected (STATE)                                              56 non-null     int64
#  13  Fistula Rate - As Expected (STATE)                                                       56 non-null     int64
#  14  Fistula Rate - Worse Than Expected (STATE)                                               56 non-null     int64
#  15  Percentage Of Adult Patients With Long Term Catheter In Use                              55 non-null     float64
#  16  Percentage Of Adult Patients With Hypercalcemia (Serum Calcium Greater Than 10.2 Mg/dL)  55 non-null     float64
#  17  Percentage Of Adult Patients With Serum Phosphorus Less Than 3.5 Mg/dL                   55 non-null     float64
#  18  Percentage Of Adult Patients With Serum Phosphorus Between 3.5-4.5 Mg/dL                 55 non-null     float64
#  19  Percentage Of Adult Patients With Serum Phosphorus Between 4.6-5.5 Mg/dL                 55 non-null     float64
#  20  Percentage Of Adult Patients With Serum Phosphorus Between 5.6-7.0 Mg/dL                 55 non-null     float64
#  21  Percentage Of Adult Patients With Serum Phosphorus Greater Than 7.0 Mg/dL                55 non-null     float64
#  22  Hospitalizations- Better Than Expected (STATE)                                           56 non-null     int64
#  23  Hospitalizations- As Expected (STATE)                                                    56 non-null     int64
#  24  Hospitalizations- Worse Than Expected (STATE)                                            56 non-null     int64
#  25  Hospital Readmission - Better Than Expected (STATE)                                      56 non-null     int64
#  26  Hospital Readmission - As Expected (STATE)                                               56 non-null     int64
#  27  Hospital  Readmission - Worse Than Expected (STATE)                                      56 non-null     int64
#  28  Survival- Better Than Expected (STATE)                                                   56 non-null     int64
#  29  Survival- As Expected (STATE)                                                            56 non-null     int64
#  30  Survival- Worse Than Expected (STATE)                                                    56 non-null     int64
#  31  Incident Patients Transplant Waitlisting- Better Than Expected (STATE)                   56 non-null     int64
#  32  Incident Patients Transplant Waitlisting - As Expected (STATE)                           56 non-null     int64
#  33  Incident Patients Transplant Waitlisting - Worse Than Expected (STATE)                   56 non-null     int64
#  34  Prevalent Patients Transplant Waitlisting- Better Than Expected (STATE)                  56 non-null     int64
#  35  Prevalent Patients Transplant Waitlisting - As Expected (STATE)                          56 non-null     int64
#  36  Prevalent Patients Transplant Waitlisting - Worse Than Expected (STATE)                  56 non-null     int64
#  37  Percentage Of Patients With Hgb<10 g/dL                                                  55 non-null     float64
#  38  Percentage of patients with Hgb>12 g/dL                                                  55 non-null     float64
# dtypes: float64(14), int64(24), object(1)
# memory usage: 17.2+ KB

# %%
train_data.columns
# Out:
# Index(['State', 'Transfusions- Better than expected (STATE)',
#        'Transfusions- As expected (STATE)',
#        'Transfusions- Worse than expected (STATE)',
#        'Infection- Better than expected (STATE)',
#        'Infection- As expected (STATE)',
#        'Infection- Worse than expected (STATE)',
#        'Percentage of adult HD patients with Kt/V>=1.2',
#        'Percentage Of Adult PD Patients With Kt/V>=1.7',
#        'Percentage Of Pediatric HD Patients With Kt/V>=1.2',
#        'Percentage Of Pediatric PD Patients With Kt/V>=1.8',
#        'Percentage Of Pediatric HD Patients With nPCR In Use',
#        'Fistula Rate - Better Than Expected (STATE)',
#        'Fistula Rate - As Expected (STATE)',
#        'Fistula Rate - Worse Than Expected (STATE)',
#        'Percentage Of Adult Patients With Long Term Catheter In Use',
#        'Percentage Of Adult Patients With Hypercalcemia (Serum Calcium Greater Than 10.2 Mg/dL)',
#        'Percentage Of Adult Patients With Serum Phosphorus Less Than 3.5 Mg/dL',
#        'Percentage Of Adult Patients With Serum Phosphorus Between 3.5-4.5 Mg/dL',
#        'Percentage Of Adult Patients With Serum Phosphorus Between 4.6-5.5 Mg/dL',
#        'Percentage Of Adult Patients With Serum Phosphorus Between 5.6-7.0 Mg/dL',
#        'Percentage Of Adult Patients With Serum Phosphorus Greater Than 7.0 Mg/dL',
#        'Hospitalizations- Better Than Expected (STATE)',
#        'Hospitalizations- As Expected (STATE)',
#        'Hospitalizations- Worse Than Expected (STATE)',
#        'Hospital Readmission - Better Than Expected (STATE)',
#        'Hospital Readmission - As Expected (STATE)',
#        'Hospital  Readmission - Worse Than Expected (STATE)',
#        'Survival- Better Than Expected (STATE)',
#        'Survival- As Expected (STATE)',
#        'Survival- Worse Than Expected (STATE)',
#        'Incident Patients Transplant Waitlisting- Better Than Expected (STATE)',
#        'Incident Patients Transplant Waitlisting - As Expected (STATE)',
#        'Incident Patients Transplant Waitlisting - Worse Than Expected (STATE)',
#        'Prevalent Patients Transplant Waitlisting- Better Than Expected (STATE)',
#        'Prevalent Patients Transplant Waitlisting - As Expected (STATE)',
#        'Prevalent Patients Transplant Waitlisting - Worse Than Expected (STATE)',
#        'Percentage Of Patients With Hgb<10 g/dL',
#        'Percentage of patients with Hgb>12 g/dL'],
#       dtype='object')

# %%
train_data.head(3)
# Out:
#   State  Transfusions- Better than expected (STATE)  \
# 0    AK                                           0
# 1    AL                                           0
# 2    AR                                           0
#
#    Transfusions- As expected (STATE)  \
# 0                                  7
# 1                                133
# 2                                 41
#
#    Transfusions- Worse than expected (STATE)  \
# 0                                          1
# 1                                         10
# 2                                         16
#
#    Infection- Better than expected (STATE)  Infection- As expected (STATE)  \
# 0                                        3                               6
# 1                                       39                             116
# 2                                       24                              35
#
#    Infection- Worse than expected (STATE)  \
# 0                                       0
# 1                                       0
# 2                                       0
#
#    Percentage of adult HD patients with Kt/V>=1.2  \
# 0                                            97.0
# 1                                            96.0
# 2                                            96.0
#
#    Percentage Of Adult PD Patients With Kt/V>=1.7  \
# 0                                            93.0
# 1                                            94.0
# 2                                            91.0
#
#    Percentage Of Pediatric HD Patients With Kt/V>=1.2  \
# 0                                              100.0
# 1                                               88.0
# 2                                               95.0
#
#    Percentage Of Pediatric PD Patients With Kt/V>=1.8  \
# 0                                                NaN
# 1                                               81.0
# 2                                               97.0
#
#    Percentage Of Pediatric HD Patients With nPCR In Use  \
# 0                                              100.0
# 1                                               88.0
# 2                                               93.0
#
#    Fistula Rate - Better Than Expected (STATE)  \
# 0                                            1
# 1                                            8
# 2                                            2
#
#    Fistula Rate - As Expected (STATE)  \
# 0                                   8
# 1                                 148
# 2                                  59
#
#    Fistula Rate - Worse Than Expected (STATE)  \
# 0                                           0
# 1                                          14
# 2                                           4
#
#    Percentage Of Adult Patients With Long Term Catheter In Use  \
# 0                                               13.0
# 1                                               11.0
# 2                                               20.0
#
#    Percentage Of Adult Patients With Hypercalcemia (Serum Calcium Greater Than 10.2 Mg/dL)  \
# 0                                                1.0
# 1                                                1.0
# 2                                                2.0
#
#    Percentage Of Adult Patients With Serum Phosphorus Less Than 3.5 Mg/dL  \
# 0                                                9.0
# 1                                                8.0
# 2                                                7.0
#
#    Percentage Of Adult Patients With Serum Phosphorus Between 3.5-4.5 Mg/dL  \
# 0                                               26.0
# 1                                               21.0
# 2                                               20.0
#
#    Percentage Of Adult Patients With Serum Phosphorus Between 4.6-5.5 Mg/dL  \
# 0                                               25.0
# 1                                               28.0
# 2                                               28.0
#
#    Percentage Of Adult Patients With Serum Phosphorus Between 5.6-7.0 Mg/dL  \
# 0                                               23.0
# 1                                               24.0
# 2                                               24.0
#
#    Percentage Of Adult Patients With Serum Phosphorus Greater Than 7.0 Mg/dL  \
# 0                                               17.0
# 1                                               19.0
# 2                                               21.0
#
#    Hospitalizations- Better Than Expected (STATE)  \
# 0                                               0
# 1                                               3
# 2                                               2
#
#    Hospitalizations- As Expected (STATE)  \
# 0                                      9
# 1                                    168
# 2                                     60
#
#    Hospitalizations- Worse Than Expected (STATE)  \
# 0                                              0
# 1                                              1
# 2                                              3
#
#    Hospital Readmission - Better Than Expected (STATE)  \
# 0                                                  0
# 1                                                  8
# 2                                                  1
#
#    Hospital Readmission - As Expected (STATE)  \
# 0                                           7
# 1                                         156
# 2                                          61
#
#    Hospital  Readmission - Worse Than Expected (STATE)  \
# 0                                                  0
# 1                                                  3
# 2                                                  2
#
#    Survival- Better Than Expected (STATE)  Survival- As Expected (STATE)  \
# 0                                       0                              9
# 1                                       3                            162
# 2                                       1                             62
#
#    Survival- Worse Than Expected (STATE)  \
# 0                                      0
# 1                                      4
# 2                                      1
#
#    Incident Patients Transplant Waitlisting- Better Than Expected (STATE)  \
# 0                                                  1
# 1                                                  2
# 2                                                  0
#
#    Incident Patients Transplant Waitlisting - As Expected (STATE)  \
# 0                                                  2
# 1                                                 69
# 2                                                 37
#
#    Incident Patients Transplant Waitlisting - Worse Than Expected (STATE)  \
# 0                                                  1
# 1                                                  3
# 2                                                  3
#
#    Prevalent Patients Transplant Waitlisting- Better Than Expected (STATE)  \
# 0                                                  1
# 1                                                  2
# 2                                                  0
#
#    Prevalent Patients Transplant Waitlisting - As Expected (STATE)  \
# 0                                                  8
# 1                                                171
# 2                                                 57
#
#    Prevalent Patients Transplant Waitlisting - Worse Than Expected (STATE)  \
# 0                                                  0
# 1                                                  3
# 2                                                  7
#
#    Percentage Of Patients With Hgb<10 g/dL  \
# 0                                     18.0
# 1                                     23.0
# 2                                     20.0
#
#    Percentage of patients with Hgb>12 g/dL
# 0                                      0.0
# 1                                      0.0
# 2                                      1.0

# %%
# Drop null records
train_data = train_data.dropna()

# Drop unecessary features
#train_data = train_data.drop(['ID'], axis=1)

# Check for null values
train_data.isnull().sum()
# Out:
# State                                                                                      0
# Transfusions- Better than expected (STATE)                                                 0
# Transfusions- As expected (STATE)                                                          0
# Transfusions- Worse than expected (STATE)                                                  0
# Infection- Better than expected (STATE)                                                    0
# Infection- As expected (STATE)                                                             0
# Infection- Worse than expected (STATE)                                                     0
# Percentage of adult HD patients with Kt/V>=1.2                                             0
# Percentage Of Adult PD Patients With Kt/V>=1.7                                             0
# Percentage Of Pediatric HD Patients With Kt/V>=1.2                                         0
# Percentage Of Pediatric PD Patients With Kt/V>=1.8                                         0
# Percentage Of Pediatric HD Patients With nPCR In Use                                       0
# Fistula Rate - Better Than Expected (STATE)                                                0
# Fistula Rate - As Expected (STATE)                                                         0
# Fistula Rate - Worse Than Expected (STATE)                                                 0
# Percentage Of Adult Patients With Long Term Catheter In Use                                0
# Percentage Of Adult Patients With Hypercalcemia (Serum Calcium Greater Than 10.2 Mg/dL)    0
# Percentage Of Adult Patients With Serum Phosphorus Less Than 3.5 Mg/dL                     0
# Percentage Of Adult Patients With Serum Phosphorus Between 3.5-4.5 Mg/dL                   0
# Percentage Of Adult Patients With Serum Phosphorus Between 4.6-5.5 Mg/dL                   0
# Percentage Of Adult Patients With Serum Phosphorus Between 5.6-7.0 Mg/dL                   0
# Percentage Of Adult Patients With Serum Phosphorus Greater Than 7.0 Mg/dL                  0
# Hospitalizations- Better Than Expected (STATE)                                             0
# Hospitalizations- As Expected (STATE)                                                      0
# Hospitalizations- Worse Than Expected (STATE)                                              0
# Hospital Readmission - Better Than Expected (STATE)                                        0
# Hospital Readmission - As Expected (STATE)                                                 0
# Hospital  Readmission - Worse Than Expected (STATE)                                        0
# Survival- Better Than Expected (STATE)                                                     0
# Survival- As Expected (STATE)                                                              0
# Survival- Worse Than Expected (STATE)                                                      0
# Incident Patients Transplant Waitlisting- Better Than Expected (STATE)                     0
# Incident Patients Transplant Waitlisting - As Expected (STATE)                             0
# Incident Patients Transplant Waitlisting - Worse Than Expected (STATE)                     0
# Prevalent Patients Transplant Waitlisting- Better Than Expected (STATE)                    0
# Prevalent Patients Transplant Waitlisting - As Expected (STATE)                            0
# Prevalent Patients Transplant Waitlisting - Worse Than Expected (STATE)                    0
# Percentage Of Patients With Hgb<10 g/dL                                                    0
# Percentage of patients with Hgb>12 g/dL                                                    0
# dtype: int64

# %%
# Check duplicated rows, or records

train_data.loc[train_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [State, Transfusions- Better than expected (STATE), Transfusions- As expected (STATE), Transfusions- Worse than expected (STATE), Infection- Better than expected (STATE), Infection- As expected (STATE), Infection- Worse than expected (STATE), Percentage of adult HD patients with Kt/V>=1.2, Percentage Of Adult PD Patients With Kt/V>=1.7, Percentage Of Pediatric HD Patients With Kt/V>=1.2, Percentage Of Pediatric PD Patients With Kt/V>=1.8, Percentage Of Pediatric HD Patients With nPCR In Use, Fistula Rate - Better Than Expected (STATE), Fistula Rate - As Expected (STATE), Fistula Rate - Worse Than Expected (STATE), Percentage Of Adult Patients With Long Term Catheter In Use, Percentage Of Adult Patients With Hypercalcemia (Serum Calcium Greater Than 10.2 Mg/dL), Percentage Of Adult Patients With Serum Phosphorus Less Than 3.5 Mg/dL, Percentage Of Adult Patients With Serum Phosphorus Between 3.5-4.5 Mg/dL, Percentage Of Adult Patients With Serum Phosphorus Between 4.6-5.5 Mg/dL, Percentage Of Adult Patients With Serum Phosphorus Between 5.6-7.0 Mg/dL, Percentage Of Adult Patients With Serum Phosphorus Greater Than 7.0 Mg/dL, Hospitalizations- Better Than Expected (STATE), Hospitalizations- As Expected (STATE), Hospitalizations- Worse Than Expected (STATE), Hospital Readmission - Better Than Expected (STATE), Hospital Readmission - As Expected (STATE), Hospital  Readmission - Worse Than Expected (STATE), Survival- Better Than Expected (STATE), Survival- As Expected (STATE), Survival- Worse Than Expected (STATE), Incident Patients Transplant Waitlisting- Better Than Expected (STATE), Incident Patients Transplant Waitlisting - As Expected (STATE), Incident Patients Transplant Waitlisting - Worse Than Expected (STATE), Prevalent Patients Transplant Waitlisting- Better Than Expected (STATE), Prevalent Patients Transplant Waitlisting - As Expected (STATE), Prevalent Patients Transplant Waitlisting - Worse Than Expected (STATE), Percentage Of Patients With Hgb<10 g/dL, Percentage of patients with Hgb>12 g/dL]
# Index: []

# %%
# Descriptive statistics for numerical features
train_data.describe()
# Out:
#        Transfusions- Better than expected (STATE)  \
# count                                   43.000000
# mean                                     0.162791
# std                                      0.484534
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      2.000000
#
#        Transfusions- As expected (STATE)  \
# count                          43.000000
# mean                          125.581395
# std                           125.829104
# min                            13.000000
# 25%                            42.000000
# 50%                            86.000000
# 75%                           163.500000
# max                           596.000000
#
#        Transfusions- Worse than expected (STATE)  \
# count                                  43.000000
# mean                                    9.093023
# std                                    10.030463
# min                                     0.000000
# 25%                                     2.000000
# 50%                                     6.000000
# 75%                                    14.500000
# max                                    47.000000
#
#        Infection- Better than expected (STATE)  \
# count                                43.000000
# mean                                 50.837209
# std                                  58.221633
# min                                   2.000000
# 25%                                  17.000000
# 50%                                  29.000000
# 75%                                  63.000000
# max                                 290.000000
#
#        Infection- As expected (STATE)  Infection- Worse than expected (STATE)  \
# count                       43.000000                               43.000000
# mean                        93.232558                                1.418605
# std                         82.899491                                1.841746
# min                         11.000000                                0.000000
# 25%                         33.000000                                0.000000
# 50%                         80.000000                                1.000000
# 75%                        118.500000                                2.000000
# max                        397.000000                                8.000000
#
#        Percentage of adult HD patients with Kt/V>=1.2  \
# count                                       43.000000
# mean                                        96.651163
# std                                          1.043887
# min                                         94.000000
# 25%                                         96.000000
# 50%                                         97.000000
# 75%                                         97.000000
# max                                         99.000000
#
#        Percentage Of Adult PD Patients With Kt/V>=1.7  \
# count                                       43.000000
# mean                                        92.186047
# std                                          2.905297
# min                                         82.000000
# 25%                                         90.000000
# 50%                                         93.000000
# 75%                                         94.000000
# max                                         96.000000
#
#        Percentage Of Pediatric HD Patients With Kt/V>=1.2  \
# count                                          43.000000
# mean                                           90.162791
# std                                            10.623268
# min                                            47.000000
# 25%                                            86.000000
# 50%                                            91.000000
# 75%                                            99.000000
# max                                           100.000000
#
#        Percentage Of Pediatric PD Patients With Kt/V>=1.8  \
# count                                          43.000000
# mean                                           75.418605
# std                                            20.744744
# min                                             8.000000
# 25%                                            64.500000
# 50%                                            80.000000
# 75%                                            92.500000
# max                                           100.000000
#
#        Percentage Of Pediatric HD Patients With nPCR In Use  \
# count                                          43.000000
# mean                                           90.511628
# std                                            14.445912
# min                                            15.000000
# 25%                                            88.500000
# 50%                                            94.000000
# 75%                                            99.000000
# max                                           100.000000
#
#        Fistula Rate - Better Than Expected (STATE)  \
# count                                    43.000000
# mean                                      6.116279
# std                                      10.452180
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       2.000000
# 75%                                       6.000000
# max                                      50.000000
#
#        Fistula Rate - As Expected (STATE)  \
# count                           43.000000
# mean                           147.488372
# std                            143.445588
# min                             16.000000
# 25%                             47.500000
# 50%                            110.000000
# 75%                            179.000000
# max                            659.000000
#
#        Fistula Rate - Worse Than Expected (STATE)  \
# count                                   43.000000
# mean                                     6.674419
# std                                      8.930208
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      3.000000
# 75%                                     11.500000
# max                                     40.000000
#
#        Percentage Of Adult Patients With Long Term Catheter In Use  \
# count                                          43.000000
# mean                                           16.534884
# std                                             3.209724
# min                                            10.000000
# 25%                                            15.000000
# 50%                                            17.000000
# 75%                                            18.000000
# max                                            29.000000
#
#        Percentage Of Adult Patients With Hypercalcemia (Serum Calcium Greater Than 10.2 Mg/dL)  \
# count                                          43.000000
# mean                                            1.697674
# std                                             0.831948
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             4.000000
#
#        Percentage Of Adult Patients With Serum Phosphorus Less Than 3.5 Mg/dL  \
# count                                          43.000000
# mean                                            7.627907
# std                                             0.817174
# min                                             6.000000
# 25%                                             7.000000
# 50%                                             8.000000
# 75%                                             8.000000
# max                                             9.000000
#
#        Percentage Of Adult Patients With Serum Phosphorus Between 3.5-4.5 Mg/dL  \
# count                                          43.000000
# mean                                           23.418605
# std                                             1.546618
# min                                            20.000000
# 25%                                            22.500000
# 50%                                            23.000000
# 75%                                            24.000000
# max                                            27.000000
#
#        Percentage Of Adult Patients With Serum Phosphorus Between 4.6-5.5 Mg/dL  \
# count                                          43.000000
# mean                                           29.511628
# std                                             1.297839
# min                                            27.000000
# 25%                                            29.000000
# 50%                                            29.000000
# 75%                                            30.000000
# max                                            32.000000
#
#        Percentage Of Adult Patients With Serum Phosphorus Between 5.6-7.0 Mg/dL  \
# count                                          43.000000
# mean                                           23.255814
# std                                             1.114686
# min                                            20.000000
# 25%                                            22.500000
# 50%                                            23.000000
# 75%                                            24.000000
# max                                            26.000000
#
#        Percentage Of Adult Patients With Serum Phosphorus Greater Than 7.0 Mg/dL  \
# count                                          43.000000
# mean                                           16.209302
# std                                             2.335626
# min                                             9.000000
# 25%                                            15.000000
# 50%                                            16.000000
# 75%                                            18.000000
# max                                            21.000000
#
#        Hospitalizations- Better Than Expected (STATE)  \
# count                                       43.000000
# mean                                         1.488372
# std                                          2.472439
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          1.000000
# 75%                                          2.000000
# max                                         15.000000
#
#        Hospitalizations- As Expected (STATE)  \
# count                              43.000000
# mean                              155.651163
# std                               150.671020
# min                                16.000000
# 25%                                52.500000
# 50%                               112.000000
# 75%                               187.500000
# max                               675.000000
#
#        Hospitalizations- Worse Than Expected (STATE)  \
# count                                       43.00000
# mean                                         6.27907
# std                                         11.96687
# min                                          0.00000
# 25%                                          0.00000
# 50%                                          2.00000
# 75%                                          5.50000
# max                                         67.00000
#
#        Hospital Readmission - Better Than Expected (STATE)  \
# count                                          43.000000
# mean                                            3.023256
# std                                             3.432952
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             4.500000
# max                                            17.000000
#
#        Hospital Readmission - As Expected (STATE)  \
# count                                   43.000000
# mean                                   151.418605
# std                                    149.662833
# min                                     15.000000
# 25%                                     49.500000
# 50%                                    111.000000
# 75%                                    180.500000
# max                                    665.000000
#
#        Hospital  Readmission - Worse Than Expected (STATE)  \
# count                                          43.000000
# mean                                            4.511628
# std                                             6.843043
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             6.000000
# max                                            38.000000
#
#        Survival- Better Than Expected (STATE)  Survival- As Expected (STATE)  \
# count                               43.000000                      43.000000
# mean                                 4.465116                     150.255814
# std                                  5.483086                     147.841790
# min                                  0.000000                      15.000000
# 25%                                  1.000000                      50.000000
# 50%                                  3.000000                     114.000000
# 75%                                  5.500000                     178.500000
# max                                 24.000000                     657.000000
#
#        Survival- Worse Than Expected (STATE)  \
# count                              43.000000
# mean                                5.279070
# std                                 6.522217
# min                                 0.000000
# 25%                                 1.000000
# 50%                                 3.000000
# 75%                                 7.500000
# max                                24.000000
#
#        Incident Patients Transplant Waitlisting- Better Than Expected (STATE)  \
# count                                          43.000000
# mean                                            5.976744
# std                                            10.762564
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             6.000000
# max                                            52.000000
#
#        Incident Patients Transplant Waitlisting - As Expected (STATE)  \
# count                                          43.000000
# mean                                           77.930233
# std                                            90.164505
# min                                             2.000000
# 25%                                            25.000000
# 50%                                            57.000000
# 75%                                            87.000000
# max                                           420.000000
#
#        Incident Patients Transplant Waitlisting - Worse Than Expected (STATE)  \
# count                                          43.000000
# mean                                            3.511628
# std                                             6.130999
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             3.000000
# max                                            34.000000
#
#        Prevalent Patients Transplant Waitlisting- Better Than Expected (STATE)  \
# count                                          43.000000
# mean                                           10.046512
# std                                            27.559419
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             6.000000
# max                                           168.000000
#
#        Prevalent Patients Transplant Waitlisting - As Expected (STATE)  \
# count                                          43.000000
# mean                                          153.209302
# std                                           150.032942
# min                                            11.000000
# 25%                                            47.000000
# 50%                                           111.000000
# 75%                                           187.000000
# max                                           714.000000
#
#        Prevalent Patients Transplant Waitlisting - Worse Than Expected (STATE)  \
# count                                          43.000000
# mean                                            3.395349
# std                                             3.761582
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             5.000000
# max                                            18.000000
#
#        Percentage Of Patients With Hgb<10 g/dL  \
# count                                43.000000
# mean                                 20.441860
# std                                   3.534202
# min                                  11.000000
# 25%                                  18.000000
# 50%                                  21.000000
# 75%                                  23.000000
# max                                  29.000000
#
#        Percentage of patients with Hgb>12 g/dL
# count                                43.000000
# mean                                  0.232558
# std                                   0.427463
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000

# %%
# Descriptive statistics for categorical features
train_data.describe(include = "object")
# Out:
#        State
# count     43
# unique    43
# top       AL
# freq       1

# %% [markdown]
# # 02 - EDA

# %%
# import ydata_profiling

# # Create EDA report
# eda_report = ydata_profiling.ProfileReport(train_original)
# #eda_report

# # Export the report to a file
# eda_report.to_file("dialysis_eda_report.html")

# %% [markdown]
# # 03 - Feature Engineering
# ## Create the X, Y matrices

# %%
# Define features X-matrix
X = train_data.drop(['Survival- As Expected (STATE)', 'State'], axis=1)

# Define target y-matrix
y = train_data['Survival- As Expected (STATE)']

# Records comparison for the X-matrix, Y-matrix
train_data.shape, X.shape, y.shape
# Out:
# ((43, 39), (43, 37), (43,))

# %%
X.head()
# Out:
#    Transfusions- Better than expected (STATE)  \
# 1                                           0
# 2                                           0
# 4                                           0
# 5                                           2
# 6                                           0
#
#    Transfusions- As expected (STATE)  \
# 1                                133
# 2                                 41
# 4                                 99
# 5                                596
# 6                                 52
#
#    Transfusions- Worse than expected (STATE)  \
# 1                                         10
# 2                                         16
# 4                                          3
# 5                                         15
# 6                                          4
#
#    Infection- Better than expected (STATE)  Infection- As expected (STATE)  \
# 1                                       39                             116
# 2                                       24                              35
# 4                                       50                              68
# 5                                      290                             298
# 6                                       20                              52
#
#    Infection- Worse than expected (STATE)  \
# 1                                       0
# 2                                       0
# 4                                       0
# 5                                       1
# 6                                       1
#
#    Percentage of adult HD patients with Kt/V>=1.2  \
# 1                                            96.0
# 2                                            96.0
# 4                                            97.0
# 5                                            97.0
# 6                                            98.0
#
#    Percentage Of Adult PD Patients With Kt/V>=1.7  \
# 1                                            94.0
# 2                                            91.0
# 4                                            94.0
# 5                                            88.0
# 6                                            91.0
#
#    Percentage Of Pediatric HD Patients With Kt/V>=1.2  \
# 1                                               88.0
# 2                                               95.0
# 4                                               98.0
# 5                                               87.0
# 6                                               89.0
#
#    Percentage Of Pediatric PD Patients With Kt/V>=1.8  \
# 1                                               81.0
# 2                                               97.0
# 4                                               86.0
# 5                                               61.0
# 6                                               64.0
#
#    Percentage Of Pediatric HD Patients With nPCR In Use  \
# 1                                               88.0
# 2                                               93.0
# 4                                               99.0
# 5                                               91.0
# 6                                               99.0
#
#    Fistula Rate - Better Than Expected (STATE)  \
# 1                                            8
# 2                                            2
# 4                                            3
# 5                                           44
# 6                                           12
#
#    Fistula Rate - As Expected (STATE)  \
# 1                                 148
# 2                                  59
# 4                                 119
# 5                                 593
# 6                                  68
#
#    Fistula Rate - Worse Than Expected (STATE)  \
# 1                                          14
# 2                                           4
# 4                                           0
# 5                                          12
# 6                                           0
#
#    Percentage Of Adult Patients With Long Term Catheter In Use  \
# 1                                               11.0
# 2                                               20.0
# 4                                               15.0
# 5                                               15.0
# 6                                               14.0
#
#    Percentage Of Adult Patients With Hypercalcemia (Serum Calcium Greater Than 10.2 Mg/dL)  \
# 1                                                1.0
# 2                                                2.0
# 4                                                1.0
# 5                                                2.0
# 6                                                1.0
#
#    Percentage Of Adult Patients With Serum Phosphorus Less Than 3.5 Mg/dL  \
# 1                                                8.0
# 2                                                7.0
# 4                                                8.0
# 5                                                8.0
# 6                                                7.0
#
#    Percentage Of Adult Patients With Serum Phosphorus Between 3.5-4.5 Mg/dL  \
# 1                                               21.0
# 2                                               20.0
# 4                                               23.0
# 5                                               24.0
# 6                                               24.0
#
#    Percentage Of Adult Patients With Serum Phosphorus Between 4.6-5.5 Mg/dL  \
# 1                                               28.0
# 2                                               28.0
# 4                                               29.0
# 5                                               31.0
# 6                                               30.0
#
#    Percentage Of Adult Patients With Serum Phosphorus Between 5.6-7.0 Mg/dL  \
# 1                                               24.0
# 2                                               24.0
# 4                                               22.0
# 5                                               22.0
# 6                                               23.0
#
#    Percentage Of Adult Patients With Serum Phosphorus Greater Than 7.0 Mg/dL  \
# 1                                               19.0
# 2                                               21.0
# 4                                               18.0
# 5                                               16.0
# 6                                               15.0
#
#    Hospitalizations- Better Than Expected (STATE)  \
# 1                                               3
# 2                                               2
# 4                                               0
# 5                                              15
# 6                                               0
#
#    Hospitalizations- As Expected (STATE)  \
# 1                                    168
# 2                                     60
# 4                                    120
# 5                                    675
# 6                                     80
#
#    Hospitalizations- Worse Than Expected (STATE)  \
# 1                                              1
# 2                                              3
# 4                                              3
# 5                                              6
# 6                                              0
#
#    Hospital Readmission - Better Than Expected (STATE)  \
# 1                                                  8
# 2                                                  1
# 4                                                  3
# 5                                                 17
# 6                                                  3
#
#    Hospital Readmission - As Expected (STATE)  \
# 1                                         156
# 2                                          61
# 4                                         119
# 5                                         645
# 6                                          72
#
#    Hospital  Readmission - Worse Than Expected (STATE)  \
# 1                                                  3
# 2                                                  2
# 4                                                  0
# 5                                                 15
# 6                                                  1
#
#    Survival- Better Than Expected (STATE)  \
# 1                                       3
# 2                                       1
# 4                                       1
# 5                                      11
# 6                                       2
#
#    Survival- Worse Than Expected (STATE)  \
# 1                                      4
# 2                                      1
# 4                                      6
# 5                                     23
# 6                                      1
#
#    Incident Patients Transplant Waitlisting- Better Than Expected (STATE)  \
# 1                                                  2
# 2                                                  0
# 4                                                  0
# 5                                                 52
# 6                                                  5
#
#    Incident Patients Transplant Waitlisting - As Expected (STATE)  \
# 1                                                 69
# 2                                                 37
# 4                                                 83
# 5                                                400
# 6                                                 35
#
#    Incident Patients Transplant Waitlisting - Worse Than Expected (STATE)  \
# 1                                                  3
# 2                                                  3
# 4                                                 11
# 5                                                 34
# 6                                                  0
#
#    Prevalent Patients Transplant Waitlisting- Better Than Expected (STATE)  \
# 1                                                  2
# 2                                                  0
# 4                                                  0
# 5                                                168
# 6                                                  4
#
#    Prevalent Patients Transplant Waitlisting - As Expected (STATE)  \
# 1                                                171
# 2                                                 57
# 4                                                119
# 5                                                550
# 6                                                 77
#
#    Prevalent Patients Transplant Waitlisting - Worse Than Expected (STATE)  \
# 1                                                  3
# 2                                                  7
# 4                                                  6
# 5                                                  1
# 6                                                  2
#
#    Percentage Of Patients With Hgb<10 g/dL  \
# 1                                     23.0
# 2                                     20.0
# 4                                     17.0
# 5                                     16.0
# 6                                     22.0
#
#    Percentage of patients with Hgb>12 g/dL
# 1                                      0.0
# 2                                      1.0
# 4                                      0.0
# 5                                      1.0
# 6                                      1.0

# %% [markdown]
# ## Feature Scaling

# %%
# Standardization
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

# %% [markdown]
# ## Logistic Regression - Full Model

# %%
random_state = 95
X_train, X_test, y_train, y_test = \
    train_test_split(X, y,
                     test_size = 0.3,
                     shuffle = True,
                     random_state=random_state)
#---train the model using Multiple Linear Regression---
log_reg = LinearRegression()
log_reg.fit(X_train, y_train)
#---evaluate the model---
log_reg.score(X_test,y_test)
# Out:
# 0.9959280985297583

# %% [markdown]
# ## PCA to X-matrix

# %%
from sklearn.decomposition import PCA
components = None
pca = PCA(n_components = components)
# perform PCA on the scaled data
pca.fit(X_scaled)
# Out:
# PCA()

# %%
# print the explained variances
print("Variances (Percentage):")
print(pca.explained_variance_ratio_ * 100)
print()
# Out:
# Variances (Percentage):
# [3.95867072e+01 1.22429920e+01 9.67117697e+00 7.17884687e+00
#  5.96114002e+00 4.14639915e+00 3.46788521e+00 2.91318299e+00
#  2.27434324e+00 1.90251913e+00 1.67451804e+00 1.32272748e+00
#  1.19951227e+00 1.17731653e+00 9.01362073e-01 8.39101611e-01
#  6.83702639e-01 5.13896184e-01 4.68799050e-01 3.79783977e-01
#  3.20603604e-01 2.59647860e-01 2.10858542e-01 1.85405184e-01
#  1.72146520e-01 1.20392406e-01 8.01488672e-02 6.58287616e-02
#  4.04023124e-02 1.56163301e-02 1.49564888e-02 4.59512611e-03
#  2.18392320e-03 1.01683310e-03 1.82241156e-04 7.18495217e-05
#  3.04997820e-05]

# %%
print("Cumulative Variances (Percentage):")
print(pca.explained_variance_ratio_.cumsum() * 100)
print()
# Out:
# Cumulative Variances (Percentage):
# [ 39.58670722  51.82969921  61.50087618  68.67972305  74.64086307
#   78.78726222  82.25514743  85.16833042  87.44267367  89.3451928
#   91.01971084  92.34243832  93.54195059  94.71926712  95.62062919
#   96.4597308   97.14343344  97.65732963  98.12612868  98.50591265
#   98.82651626  99.08616412  99.29702266  99.48242784  99.65457436
#   99.77496677  99.85511563  99.9209444   99.96134671  99.97696304
#   99.99191953  99.99651465  99.99869858  99.99971541  99.99989765
#   99.9999695  100.        ]

# %%
import matplotlib.pyplot as plt

# scree plot
components = len(pca.explained_variance_ratio_) \
    if components is None else components
plt.plot(range(1,components+1), 
         np.cumsum(pca.explained_variance_ratio_ * 100))
plt.xlabel("Number of components")
plt.ylabel("Explained variance (%)")
# Out:
# Text(0, 0.5, 'Explained variance (%)')

# %% [markdown]
# <font size='5'>Let’s now apply PCA to find the desired number of components based on the desired explained variance.<font>

# %%
pca = PCA(n_components = 0.86)
pca.fit(X_scaled)
print("Cumulative Variances (Percentage):")
print(np.cumsum(pca.explained_variance_ratio_ * 100))
components = len(pca.explained_variance_ratio_)
print(f'Number of components: {components}')
# Make the scree plot
plt.plot(range(1, components + 1), np.cumsum(pca.explained_variance_ratio_ * 100))
plt.xlabel("Number of components")
plt.ylabel("Explained variance (%)")
# Out:
# Cumulative Variances (Percentage):
# [39.58670722 51.82969921 61.50087618 68.67972305 74.64086307 78.78726222
#  82.25514743 85.16833042 87.44267367]
# Number of components: 9
# Text(0, 0.5, 'Explained variance (%)')

# %% [markdown]
# <font size='5'>You can also find out the importance of each feature that contributes to each of the components using the components_ attribute of the pca object<font>

# %%
pca_components = abs(pca.components_)
print(pca_components)
# Out:
# [[7.40395447e-02 2.56692737e-01 2.01105440e-01 2.56098117e-01
#   2.46708421e-01 1.27579730e-01 7.76916735e-02 7.00089738e-02
#   4.83996301e-02 2.72698251e-02 4.06174082e-02 1.66944097e-01
#   2.54926221e-01 1.88569092e-01 3.29272539e-02 7.54720357e-02
#   1.38665446e-02 2.34939406e-02 5.66427991e-02 5.73190579e-02
for row in range(pca_components.shape[0]):
    # get the indices of the top 4 values in each row
    temp = np.argpartition(-(pca_components[row]), 4)
    
    # sort the indices in descending order
    indices = temp[np.argsort((-pca_components[row])[temp])][:4]
    
    # print the top 4 feature names
    print(f'Component {row}: {train_data.columns[indices].to_list()}')
# Out:
# Top 4 most important features in each component
# ===============================================
# Component 0: ['Hospital Readmission - Better Than Expected (STATE)', 'Transfusions- Better than expected (STATE)', 'Hospitalizations- Better Than Expected (STATE)', 'Transfusions- Worse than expected (STATE)']
# Component 1: ['Percentage Of Adult Patients With Serum Phosphorus Less Than 3.5 Mg/dL', 'Percentage Of Adult Patients With Serum Phosphorus Between 5.6-7.0 Mg/dL', 'Percentage Of Adult Patients With Serum Phosphorus Between 4.6-5.5 Mg/dL', 'Percentage Of Adult Patients With Serum Phosphorus Between 3.5-4.5 Mg/dL']
# Component 2: ['Percentage Of Adult Patients With Serum Phosphorus Greater Than 7.0 Mg/dL', 'Hospitalizations- As Expected (STATE)', 'Fistula Rate - Worse Than Expected (STATE)', 'Percentage Of Adult Patients With Serum Phosphorus Between 5.6-7.0 Mg/dL']
# Component 3: ['Infection- Worse than expected (STATE)', 'Percentage of adult HD patients with Kt/V>=1.2', 'Prevalent Patients Transplant Waitlisting - As Expected (STATE)', 'Percentage Of Adult Patients With Long Term Catheter In Use']
# Component 4: ['Percentage Of Adult PD Patients With Kt/V>=1.7', 'Percentage Of Pediatric PD Patients With Kt/V>=1.8', 'Percentage Of Pediatric HD Patients With Kt/V>=1.2', 'Percentage Of Adult Patients With Long Term Catheter In Use']
# Component 5: ['Prevalent Patients Transplant Waitlisting - Worse Than Expected (STATE)', 'Fistula Rate - Worse Than Expected (STATE)', 'Percentage Of Adult Patients With Hypercalcemia (Serum Calcium Greater Than 10.2 Mg/dL)', 'Prevalent Patients Transplant Waitlisting - As Expected (STATE)']
# Component 6: ['Percentage Of Pediatric HD Patients With Kt/V>=1.2', 'Prevalent Patients Transplant Waitlisting - Worse Than Expected (STATE)', 'Prevalent Patients Transplant Waitlisting - As Expected (STATE)', 'State']
# Component 7: ['Percentage of adult HD patients with Kt/V>=1.2', 'Percentage Of Adult Patients With Long Term Catheter In Use', 'Prevalent Patients Transplant Waitlisting - Worse Than Expected (STATE)', 'Infection- As expected (STATE)']
# Component 8: ['Percentage Of Adult Patients With Hypercalcemia (Serum Calcium Greater Than 10.2 Mg/dL)', 'Percentage Of Pediatric HD Patients With Kt/V>=1.2', 'Percentage Of Adult Patients With Serum Phosphorus Between 3.5-4.5 Mg/dL', 'Fistula Rate - As Expected (STATE)']

# %% [markdown]
# ## Transforming all the Columns to the (n) Principal Components

# %%
# transform the standardized data of the columns in the dataset to the (n) principal components
X_pca = pca.transform(X_scaled)
print(X_pca.shape)
print(X_pca)
# Out:
# (43, 9)
# [[-7.77212217e-02 -2.13573103e+00  1.85606033e+00  3.50923215e-01
#   -1.50094829e-01  1.64980397e+00  8.29463874e-02  7.83328884e-01
#    5.14626389e-01]
#  [-1.99396766e+00 -2.45510384e+00  9.24870463e-01 -6.67496714e-02
#   -2.20913701e+00 -2.22801744e+00 -8.23028064e-01  2.78213017e-01
#    9.65498809e-01]
#  [-1.19302517e+00  2.88161929e-02  6.09812489e-01 -1.48486033e+00
#   -9.03446003e-01  8.18615689e-01  7.06122734e-01  1.31613770e-01
#    3.57438161e-01]
#  [ 1.36827577e+01  4.86517388e+00  7.10610688e+00 -1.33587099e+00
#   -2.29636095e-01 -5.95538700e-01 -1.55652754e+00 -9.34972202e-01
#    3.85055054e-01]
#  [ 4.73029501e-01 -4.87586586e+00  1.61687664e+00  1.21980134e+00
#    5.35151887e+00 -1.44805940e+00 -6.58705691e-01 -1.80215785e+00
#    1.28189017e+00]
#  [ 1.16234853e+01 -2.54528525e+00  3.75384429e-01 -1.25788157e+00
#   -1.11031640e+00  9.58485130e-01  1.25414693e+00  4.98474366e-01
#   -1.21047643e+00]
#  [-3.07256168e+00 -1.31825013e+00  1.46794976e+00  2.18595953e+00
#   -2.06692692e+00 -3.40363574e-01 -1.27237196e+00  8.45687726e-01
#    1.26094591e+00]
#  [ 8.02220179e-01 -3.10730018e-01  4.70971175e-01 -5.30730445e-01
#    4.98841823e-01  5.44274654e-01 -9.76037909e-01 -6.37192457e-01
#   -1.65840777e+00]
#  [-1.68383240e+00 -1.70098563e+00  2.21168169e+00 -1.13191405e-02
#   -1.23081422e+00 -1.27206962e+00  1.72476369e+00 -1.48827752e-01
#    3.08372236e-02]
#  [-1.01482492e+00  5.34044615e-01 -1.17690377e+00  6.34579390e-01
#    4.27231225e-01 -4.14674237e-02 -4.15154330e-01 -3.60378161e-01
#   -1.98220594e-01]]

# %% [markdown]
# # 04 - Modeling
# ## Create Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


_sc = StandardScaler()
_pca = PCA(n_components = components)
_model = LinearRegression()
linear_reg_model = Pipeline([
    ('std_scaler', _sc),
    ('pca', _pca),
    ('regressor', _model)
])

# %% [markdown]
# ## Data split into Training, and Test sets

# %%
# perform a split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=random_state)

# %% [markdown]
# ## Train, and Predict using Pipeline

# %%
# train the model using the PCA components
linear_reg_model.fit(X_train,y_train)

# Use the pipeline to make predictions
y_pred = linear_reg_model.predict(X_test)

# %% [markdown]
# ## Model Evaluation

# %%
import math

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
rmse = math.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared:", r2)
# Out:
# Mean Squared Error (MSE): 351.2432993831002
# Root Mean Squared Error (RMSE): 18.741486050553732
# R-squared: 0.9524699273632521

# %%
# Calculate the adjusted R-squared
n = len(y)  # Number of observations
p = len(X.columns)  # Number of predictors (independent variables/features)
adjusted_r_squared = 1 - ((1 - r2) * (n - 1)/ (n - p - 1))

print(n, p)
print("Adjusted R-squared:", adjusted_r_squared)
# Out:
# 43 37
# Adjusted R-squared: 0.6007473898513176

# %%
# Extract coefficients and intercept from the model
coefficients = _model.coef_
intercept = _model.intercept_

# Print coefficients and intercept
print("Coefficients:", coefficients)
print("Intercept:", intercept)
# Out:
# Coefficients: [ 41.37095787 -10.38720267  -3.77138362  -0.38494237   5.77235425
#   -2.74720114  -3.13865193  -4.16429987  20.39654665]
# Intercept: 153.36666666666667

# %% [markdown]
# # 05 - Kernel PCA

# %%
from sklearn.decomposition import KernelPCA

# Split the data into training and testing sets
X_train_k, X_test_k, y_train_k, y_test_k = train_test_split(X, y, test_size=0.2, random_state=random_state)

# Create a Kernel PCA transformer
kpca = KernelPCA(n_components=8, kernel='linear')

# Create a linear regression model
multiple_reg_model = LinearRegression()

# Create a pipeline that combines Kernel PCA and Linear Regression
kernel_pipeline = Pipeline([
    ('kpca', kpca),
    ('regressor', multiple_reg_model)
])

# Fit the pipeline to the training data
kernel_pipeline.fit(X_train_k, y_train_k)

# Make predictions on the test data
y_pred_k = kernel_pipeline.predict(X_test_k)

# %%
# Evaluate the model
mse = mean_squared_error(y_test_k, y_pred_k)
r2 = r2_score(y_test_k, y_pred_k)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 13.541271861408841
# R-squared: 0.9979700347183476

# %%
# Calculate the adjusted R-squared
n = len(y)  # Number of observations
p = len(X.columns)  # Number of predictors (independent variables/features)
adjusted_r_squared = 1 - ((1 - r2) * (n - 1)/ (n - p - 1))

print(n, p)
print("Adjusted R-squared:", adjusted_r_squared)
# Out:
# 43 37
# Adjusted R-squared: 0.9829482916341195

# %%
# Extract coefficients and intercept from the model
coefficients = multiple_reg_model.coef_
intercept = multiple_reg_model.intercept_

# Print coefficients and intercept
print("Coefficients:", coefficients)
print("Intercept:", intercept)
# Out:
# Coefficients: [ 0.42430209  0.0197694   0.13926614  0.02821899  0.01383607  0.24108043
#  -0.13384405  0.17962443]
# Intercept: 151.00000000000023

# %% [markdown]
# # 06 - Graphs

# %%
import matplotlib.pyplot as plt

# Perform Kernel PCA on the training data
X_train_kpca = kpca.transform(X_train_k)

# Plot the first two principal components
plt.figure(figsize=(8, 6))
plt.scatter(X_train_kpca[:, 0], X_train_kpca[:, 1], c=y_train_k, cmap=plt.cm.Paired)
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title('Kernel PCA - First Two Principal Components')
plt.colorbar(label='Target Value')
plt.show()
plt.close()

# %%
# from matplotlib.colors import ListedColormap

# # # Perform Kernel PCA on the training data
# # X_train_kpca = kpca.transform(X_train_k)

# # # Plot the first two principal components
# # plt.figure(figsize=(8, 6))
# # plt.scatter(X_train_kpca[:, 0], X_train_kpca[:, 1], c=y_train_k, cmap=plt.cm.coolwarm)

# # Number of components to visualize
# num_components = 8

# # Create a colormap for decision regions
# cmap = ListedColormap(('red', 'green', 'blue'))

# # Create a grid of subplots for all combinations of 2 components
# fig, axes = plt.subplots(num_components, num_components, figsize=(15, 10))

# # Iterate through all combinations of 2 components
# for i in range(num_components):
#     for j in range(num_components):
#         if i != j:  # Skip diagonal plots
#             ax = axes[i, j]
            
#             # Create a meshgrid for the decision boundary
#             x1_min, x1_max = X_set.values[:, i].min() - 1, X_set.values[:, i].max() + 1
#             x2_min, x2_max = X_set.values[:, j].min() - 1, X_set.values[:, j].max() + 1
#             X1, X2 = np.meshgrid(np.arange(start=x1_min, stop=x1_max, step=0.01),
#                                  np.arange(start=x2_min, stop=x2_max, step=0.01))
            
#             # Predict using the kernel pipeline and reshape for contour plot
#             Z = kernel_pipeline.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape)
            
#             # Plot the decision regions on the current subplot
#             ax.contourf(X1, X2, Z, alpha=0.6, cmap=cmap)
#             ax.set_xlim(X1.min(), X1.max())
#             ax.set_ylim(X2.min(), X2.max())
            
#             # Plot the data points on the current subplot
#             for k, cls in enumerate(np.unique(y_set)):
#                 ax.scatter(X_set[y_set == cls, i], X_set[y_set == cls, j], c=cmap(k), label=cls)
            
#             # Set labels and title for the current subplot
#             ax.set_xlabel(f'PC{i + 1}')
#             ax.set_ylabel(f'PC{j + 1}')
#             ax.set_title(f'PC{i + 1} vs. PC{j + 1}')
#             ax.legend()

# # Adjust the layout of subplots
# plt.tight_layout()
# plt.show()
